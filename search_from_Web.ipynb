# %%
import requests
import urllib.parse
from bs4 import BeautifulSoup

def search_sap_docs(query):
    # URL encode the query
    encoded_query = urllib.parse.quote_plus(query)
    
    # Define the URL
    url = f"https://help.sap.com/http.svc/elasticsearch?area=content&version=&language=en-US&state=PRODUCTION&q={encoded_query}&transtype=standard,html,pdf,others&product=&to=19&advancedSearch=0&excludeNotSearchable=1"
    
    # Send the request
    response = requests.get(url)
    
    # If the request was successful, return the JSON response
    if response.status_code == 200:
        return response.json()
    else:
        return f"Request failed with status code {response.status_code}"

def print_response(response):
    # Check if the status is OK
    if response.get('status') == 'OK':
        # Get the data
        data = response.get('data', {})

        # Get the results
        results = data.get('results', [])

        # Loop through each result and print the details
        for i, result in enumerate(results, 1):
            print(f"Result {i}:")
            print(f"Title: {result.get('title', 'N/A')}")
            print(f"Date: {result.get('date', 'N/A')}")
            print(f"Product: {result.get('product', 'N/A')}")
            print(f"URL: https://help.sap.com{result.get('url', 'N/A')}")
            
            # Parse the snippet as HTML and get the text
            snippet_soup = BeautifulSoup(result.get('snippet', 'N/A'), 'html.parser')
            print(f"Snippet: {snippet_soup.get_text()}")
            print("\n")

# Test the function
query = "Returns Management Doc"
response = search_sap_docs(query)
print_response(response)
# Out:
# Result 1:
# Title: API Tutorial for SAP Asset Strategy and Performance Management
# Date: 2022-08-22
# Product: SAP Asset Strategy and Performance Management
# URL: https://help.sap.com/doc/b8910c849b05444fadfd03037bc3c829/2208/en-US/loiodda72b5b65154fb88a5ebd0fe7a77fcb.pdf
# Snippet: GET Returns company profile lo­ cation ... GET Returns subsidiaries infor­ mation ... GET Returns details of a failure mode ... GET Return details of detection methods ... GET Returns details of failure mode ...
#
#
# Result 2:
# Title: CreditBlockedSalesDocument | SAP Cloud SDK for JavaScript / TypeScript - v1.26.0
# Date: 2021-06-03
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/c6112985e09f40ec97dd43ad791ebaef/1.0/en-US/classes/vdm_op_sales_doc_with_credit_block_service.creditblockedsalesdocument-1.html
# Snippet: Returns CreditBlockedSalesDocument ... Returns \{} ... Returns an entity builder to construct instances of CreditBlockedSalesDocument. ... Returns CustomField<CreditBlockedSalesDocument> ... Returns CreditBlockedSalesDocumentRequestBuilder ...
#
#
# Result 3:
# Title: Managing Dependencies with ABAP Unit
# Date: 2023-01-25
# Product: SAP S/4HANA Cloud
# URL: https://help.sap.com/docs/SAP_S4HANA_CLOUD/25cf71e63940453397a32dc2b7676947/04a2d0fc9cd940db8aedf3fa29e5f07e.html?locale=en-US&state=PRODUCTION&version=2302.500
# Snippet: Managing Dependencies with ABAP Unit ... Responses received by the test from the object under test like return values or exceptions. ... Responses from the DOC, like return values or exceptions. ... The result of replacing a DOC with a test double ... Object Oriented Dependencies (DOC = Class) ...
#
#
# Result 4:
# Title: SerialNumberPhysInventoryDoc | SAP Cloud SDK for JavaScript / TypeScript - v1.27.0
# Date: 2021-08-19
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/68382f23560848b2aed3536c28cfc01a/1.0/en-US/classes/vdm_physical_inventory_doc_service.serialnumberphysinventorydoc-1.html
# Snippet: Returns SerialNumberPhysInventoryDoc ... The physical inventory document is the central element of physical inventory management. ... Returns \{} ... Returns CustomField<SerialNumberPhysInventoryDoc, false> ... Returns SerialNumberPhysInventoryDocRequestBuilder ...
#
#
# Result 5:
# Title: @sap/cloud-sdk-vdm-sales-doc-with-credit-block-service | SAP Cloud SDK for JavaScript / TypeScript
# Date: 2021-05-19
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/69202ef7e0a64767833782132648b855/1.0/en-US/modules/_sap_cloud_sdk_vdm_sales_doc_with_credit_block_service.html
# Snippet: Returns ODataBatchRequestBuilder ... Returns ODataBatchChangeSet<WriteSalesDocWithCreditBlockServiceRequestBuilder> ... Returns FunctionImportRequestBuilder<CheckCreditBlockParameters, ReturnMessage> ... Returns ReturnMessage ... Returns FunctionImportRequestBuilder<RejectCreditBlockParameters, ReturnMessage> ...
#
#
# Result 6:
# Title: CreditBlockedSalesDocument | SAP Cloud SDK for JavaScript / TypeScript
# Date: 2020-11-16
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/7383d8eedeb04e36a91f276ef8c1fa9c/1.0/en-US/classes/_sap_cloud_sdk_op_vdm_sales_doc_with_credit_block_service.creditblockedsalesdocument-1.html
# Snippet: Returns this ... Returns any ... Returns any ... The returned properties does not include custom fields. ... Returns \{} ...
#
#
# Result 7:
# Title: Creating a Template
# Date: 2019-06-30
# Product: SAP Asset Strategy and Performance Management
# URL: https://help.sap.com/docs/SAP_ASSET_STRATEGY_AND_PERFORMANCE_MANAGEMENT/76bd798328604d59bb846b97d30315e1/af31f373c5bf4cbb811a628b63e799fd.html?locale=en-US&state=PRODUCTION&version=1906
# Snippet: fields that you can use in a request payload, refer to the request schema in the https://help.sap.com/doc ... If a template is created successfully, system auto generates a template id and returns the details in ... For more information, see https://help.sap.com/doc/31356cffc27e4ef0b28bca707e50b27b/1906/en-US/Template.html ... If the template cannot be created, system returns appropriate error code in the response payload. ... For more information, see https://help.sap.com/doc/31356cffc27e4ef0b28bca707e50b27b/1906/en-US/Template.html ...
#
#
# Result 8:
# Title: CreditBlockedSalesDocument | SAP Cloud SDK for JavaScript / TypeScript
# Date: 2021-05-19
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/b73b295eedc84fb79ab27d2b5b94ba71/1.0/en-US/classes/_sap_cloud_sdk_vdm_sales_doc_with_credit_block_service.creditblockedsalesdocument-1.html
# Snippet: Returns this ... Returns any ... The returned properties does not include custom fields. ... Returns this ... Returns \{} ...
#
#
# Result 9:
# Title: CreditBlockedSalesDocument | SAP Cloud SDK for JavaScript / TypeScript - v1.25.1
# Date: 2021-05-21
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/9c2e15fd1d6a4b0a9a915e43714de149/1.0/en-US/classes/vdm_sales_doc_with_credit_block_service.creditblockedsalesdocument-1.html
# Snippet: Returns CreditBlockedSalesDocument ... Returns \{} ... Returns an entity builder to construct instances of CreditBlockedSalesDocument. ... Returns CustomField<CreditBlockedSalesDocument> ... Returns CreditBlockedSalesDocumentRequestBuilder ...
#
#
# Result 10:
# Title: CreditBlockedSalesDocument | SAP Cloud SDK for JavaScript / TypeScript
# Date: 2021-05-19
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/69202ef7e0a64767833782132648b855/1.0/en-US/classes/_sap_cloud_sdk_vdm_sales_doc_with_credit_block_service.creditblockedsalesdocument.html
# Snippet: Returns this ... Returns any ... The returned properties does not include custom fields. ... Returns this ... Returns this ...
#
#
# Result 11:
# Title: PhysInventoryDocItem | SAP Cloud SDK for JavaScript / TypeScript - v1.25.1
# Date: 2021-05-21
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/9c2e15fd1d6a4b0a9a915e43714de149/1.0/en-US/classes/vdm_physical_inventory_doc_service.physinventorydocitem-1.html
# Snippet: Returns PhysInventoryDocItem ... Returns \{} ... Returns an entity builder to construct instances of PhysInventoryDocItem. ... Returns CustomField<PhysInventoryDocItem> ... Returns PhysInventoryDocItemRequestBuilder ...
#
#
# Result 12:
# Title: PhysInventoryDocItem | SAP Cloud SDK for JavaScript / TypeScript
# Date: 2020-06-08
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/5efe819fea90462bab1173a11383d473/1.0/en-US/classes/_sap_cloud_sdk_vdm_physical_inventory_doc_service.physinventorydocitem-1.html
# Snippet: Returns this ... Returns any ... The returned properties does not include custom fields. ... Returns this ... Returns \{} ...
#
#
# Result 13:
# Title: Return to Open Orders
# Date: 2024-02-19
# Product: SAP Business One
# URL: https://help.sap.com/docs/SAP_BUSINESS_ONE/68a2e87fb29941b5bf959a184d9c6727/4633e055cb43520be10000000a44538d.html?locale=en-US&state=PRODUCTION&version=10.0
# Snippet: On the Per Document tab, do the following: ... Then select the Reopen Doc. By Creating Returns/Goods Returns/Credit Memos Based on Doc. . ... Then select the Reopen Doc. By Creating Returns/Goods Returns/Credit Memos Based on Doc. . ... This field is available only if the checkbox Reopen Doc. by Creating Returns/Goods Returns/Credit Memos ... Based on Doc. is selected. ...
#
#
# Result 14:
# Title: Viewing the Company Profile
# Date: 2019-06-30
# Product: SAP Asset Strategy and Performance Management
# URL: https://help.sap.com/docs/SAP_ASSET_STRATEGY_AND_PERFORMANCE_MANAGEMENT/76bd798328604d59bb846b97d30315e1/c2b6cb9d99fe49cbaf97784e109238ce.html?locale=en-US&state=PRODUCTION&version=1906
# Snippet: Profile This API allows you to view the profile of an organization in SAP Asset Strategy and Performance Management ... Request Schema: Refer to the request schema in the https://help.sap.com/doc/f8eb9ec0ef62415591f9fe504aaea933 ... On successful execution, the system returns the detailed information about the organization. ... For more information, see https://help.sap.com/doc/f8eb9ec0ef62415591f9fe504aaea933/1906/en-US/companyprofile.html ...
#
#
# Result 15:
# Title: Viewing Locations of the Company
# Date: 2019-06-30
# Product: SAP Asset Strategy and Performance Management
# URL: https://help.sap.com/docs/SAP_ASSET_STRATEGY_AND_PERFORMANCE_MANAGEMENT/76bd798328604d59bb846b97d30315e1/783d203503fc4a869cda8bce9937962d.html?locale=en-US&state=PRODUCTION&version=1906
# Snippet: This API allows you to view the locations of an organization in SAP Asset Strategy and Performance Management ... Request Schema: Refer to the request schema in the https://help.sap.com/doc/f8eb9ec0ef62415591f9fe504aaea933 ... On successful execution, the system returns the location information of the organization. ... For more information, see https://help.sap.com/doc/f8eb9ec0ef62415591f9fe504aaea933/1906/en-US/companyprofile.html ...
#
#
# Result 16:
# Title: PhysInventoryDocItem | SAP Cloud SDK for JavaScript / TypeScript
# Date: 2021-05-19
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/69202ef7e0a64767833782132648b855/1.0/en-US/classes/_sap_cloud_sdk_vdm_physical_inventory_doc_service.physinventorydocitem.html
# Snippet: Returns this ... Returns any ... The returned properties does not include custom fields. ... Returns this ... Returns this ...
#
#
# Result 17:
# Title: Viewing Mapped Measuring Point Values
# Date: 2017-12-04
# Product: SAP Asset Strategy and Performance Management
# URL: https://help.sap.com/docs/SAP_ASSET_STRATEGY_AND_PERFORMANCE_MANAGEMENT/76bd798328604d59bb846b97d30315e1/6916c3b6157d4351aa931c650c1a7849.html?locale=en-US&state=PRODUCTION&version=1711
# Snippet: this API to view the measuring point values of your equipment in SAP Asset Strategy and Performance Management ... Query Parameters: For details about the query parameter, see https://help.sap.com/doc/0b682a98e54a49c2ac12c55e4f9fd8b2 ... Based on the query parameters, the system returns measuring point values of the equipment. ... For more information, see https://help.sap.com/doc/0b682a98e54a49c2ac12c55e4f9fd8b2/1711/en-US/measuringPoints.html ...
#
#
# Result 18:
# Title: PhysInventoryDocHeader | SAP Cloud SDK for JavaScript / TypeScript - v1.27.0
# Date: 2021-08-19
# Product: SAP Cloud SDK
# URL: https://help.sap.com/doc/68382f23560848b2aed3536c28cfc01a/1.0/en-US/classes/vdm_physical_inventory_doc_service.physinventorydocheader-1.html
# Snippet: Returns PhysInventoryDocHeader ... Returns \{} ... Returns an entity builder to construct instances of PhysInventoryDocHeader. ... Returns CustomField<PhysInventoryDocHeader, false> ... Returns PhysInventoryDocHeaderRequestBuilder ...
#
#
# Result 19:
# Title: Viewing Subsidiaries of the Company
# Date: 2019-06-30
# Product: SAP Asset Strategy and Performance Management
# URL: https://help.sap.com/docs/SAP_ASSET_STRATEGY_AND_PERFORMANCE_MANAGEMENT/76bd798328604d59bb846b97d30315e1/96aa17169c534138b9afd4631c71d4e1.html?locale=en-US&state=PRODUCTION&version=1906
# Snippet: API allows you to view the subsidiaries of your organization in SAP Asset Strategy and Performance Management ... On successful execution, the system returns the subsidiary companies of the organization. ... For more information, see https://help.sap.com/doc/f8eb9ec0ef62415591f9fe504aaea933/1906/en-US/companyprofile.html ...
#
#
# Result 20:
# Title: Managing Documents in Approval Process
# Date: 2024-02-05
# Product: Web Client for SAP Business One
# URL: https://help.sap.com/docs/SAP_BUSINESS_ONE_WEB_CLIENT/2554bf7e9aa347729b0547a737e123ac/a7169f3ee72040d18f2dbdd19200b72d.html?locale=en-US&state=PRODUCTION&version=10.0_SP_2402
# Snippet: Managing Documents in Approval Process When trying to add or update a document that triggers an approval ... This function supports sales orders, sales quotations, A/R reserve invoices, deliveries, A/R invoices, returns ... credit memos, purchase quotations, purchase orders, A/P reserve invoices, goods receipt POs, goods returns ... To view the approval status and proceed with the process, click the Docs in Approval Process tile; the ... Manage Docs in Approval Process list view opens. ...
